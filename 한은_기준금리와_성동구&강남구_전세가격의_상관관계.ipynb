# %% [markdown]
# <a href="https://colab.research.google.com/github/yu-hyeri/first-project/blob/main/%ED%95%9C%EC%9D%80_%EA%B8%B0%EC%A4%80%EA%B8%88%EB%A6%AC%EC%99%80_%EC%84%B1%EB%8F%99%EA%B5%AC%26%EA%B0%95%EB%82%A8%EA%B5%AC_%EC%A0%84%EC%84%B8%EA%B0%80%EA%B2%A9%EC%9D%98_%EC%83%81%EA%B4%80%EA%B4%80%EA%B3%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
jeonse = pd.read_csv('/content/drive/MyDrive/개떡찰떡/DATA/monthly_apt_jeonse.csv')
jeonse
# Out:
#         지역명    2019-05    2019-06    2019-07    2019-08    2019-09    2019-10  \
# 0        전국  82.739433  82.613184  82.517175  82.498353  82.497908  82.550769
# 1        서울  78.587992  78.529117  78.552769  78.644545  78.746816  78.933886
# 2    강북14개구  78.931032  78.868462  78.886007  78.993583  79.074724  79.150134
# 3       종로구  83.602818   83.51364   83.51364  83.535077  83.707085  83.707145
# 4        중구  84.005742  84.005742  84.003095  84.005742  84.005742  84.005742
# ..      ...        ...        ...        ...        ...        ...        ...
# 273     무주군          -          -          -          -          -          -
# 274     임실군          -          -          -          -          -          -
# 275     순창군          -          -          -          -          -          -
# 276     고창군          -          -          -          -          -          -
# 277     부안군          -          -          -          -          -          -
#
#        2019-11    2019-12    2020-01  ...      2023-08      2023-09  \
# 0    82.628244  82.764992  82.931603  ...  87.60530908  87.77795417
# 1    79.099898  79.399492  79.681242  ...  84.55386904     84.91176
# 2    79.214558  79.363258  79.480687  ...  85.00666641  85.13883057
# 3    83.863709  83.936728  83.967058  ...  89.81269962  90.17090214
# 4    83.930472  83.999535   84.00879  ...  85.27879979  85.41519733
# ..         ...        ...        ...  ...          ...          ...
# 273          -          -          -  ...  111.8040213  111.8040213
# 274          -          -          -  ...   101.195498   101.195498
# 275          -          -          -  ...            -            -
# 276          -          -          -  ...  105.2622508  105.2622508
# 277          -          -          -  ...  105.4930253  105.7017971
#
#          2023-10      2023-11      2023-12      2024-01     2024-02  \
# 0    88.03195608  88.27558841   88.4090321  88.53551052   88.641814
# 1    85.44228714  85.97560884   86.3781877  86.76678481   87.008844
# 2     85.4876509  85.88213948  86.18450754  86.52661081   86.731478
# 3    90.48218735  91.01523991  91.81276627  92.39096325   92.680702
# 4    85.64796028  85.87205302   86.3817525  86.92301828   87.248875
# ..           ...          ...          ...          ...         ...
# 273  111.8040213  117.9889246  117.9889246  117.9889246  117.988925
# 274   101.195498   101.195498   101.195498  104.9014943  104.901494
# 275            -            -            -            -   99.274467
# 276  105.2622508  105.2622508  105.2622508  107.0683033  107.640547
# 277  105.7017971  105.7017971  105.7017971  105.8795675  105.702373
#
#         2024-03     2024-04     2024-05
# 0     88.805314   88.945806   89.044350
# 1     87.462183   87.996113   88.360752
# 2     87.210527   87.793347   88.193773
# 3     93.120846   93.607515   93.887104
# 4     88.097229   88.972821   89.541728
# ..          ...         ...         ...
# 273  117.988925  117.988925  117.988925
# 274  104.901494  105.749597  106.308787
# 275   99.274467   99.274467   99.274467
# 276  108.015050  108.228279  109.098842
# 277  106.898013  106.898013  106.898013
#
# [278 rows x 62 columns]

# %%
jeonse_new = jeonse.query('지역명 in["강남구", "성동구"]')
jeonse_new
# Out:
#     지역명    2019-05    2019-06    2019-07    2019-08    2019-09    2019-10  \
# 6   성동구  81.454224  81.443945  81.443664  81.625057  81.799353  81.828197
# 26  강남구  76.743374   76.64816  76.636227  76.687059  76.826387  77.484499
#
#       2019-11    2019-12    2020-01  ...      2023-08      2023-09  \
# 6   81.928449  82.078993  82.187386  ...  86.28418166  86.65124254
# 26  77.769412   78.65791  79.304564  ...  81.43815329   81.7703939
#
#         2023-10      2023-11      2023-12      2024-01    2024-02    2024-03  \
# 6   86.94418574  87.36092121   87.6478177  88.01673834  88.232170  88.721050
# 26  82.23357722   82.8086944  83.22815202  83.62476111  83.944583  84.266718
#
#       2024-04    2024-05
# 6   89.576957  89.997745
# 26  84.818628  85.264161
#
# [2 rows x 62 columns]

# %%
jeonse_dropped = jeonse_new.drop(columns=jeonse.columns[1:8])
jeonse_dropped
# Out:
#     지역명    2019-12    2020-01    2020-02    2020-03    2020-04    2020-05  \
# 6   성동구  82.078993  82.187386  82.202734  82.222013   82.25638  82.265813
# 26  강남구   78.65791  79.304564  79.742271  79.985089  80.112433  80.294087
#
#       2020-06    2020-07    2020-08  ...      2023-08      2023-09  \
# 6   82.355565  83.233108  84.346906  ...  86.28418166  86.65124254
# 26  81.085283  82.650809  83.843275  ...  81.43815329   81.7703939
#
#         2023-10      2023-11      2023-12      2024-01    2024-02    2024-03  \
# 6   86.94418574  87.36092121   87.6478177  88.01673834  88.232170  88.721050
# 26  82.23357722   82.8086944  83.22815202  83.62476111  83.944583  84.266718
#
#       2024-04    2024-05
# 6   89.576957  89.997745
# 26  84.818628  85.264161
#
# [2 rows x 55 columns]

# %%
pd.set_option('display.max_columns', None) # 모든 열을 표시
pd.set_option('display.max_rows', None) # 모든 행을 표시

# %%
jeonse_dropped.to_csv('jeonse_dropped.csv', index=False) #표 저장

# %%
import pandas as pd

jeonse_dropped = pd.read_csv('jeonse_dropped.csv')
jeonse_dropped
# Out:
#    지역명    2019-12    2020-01    2020-02    2020-03    2020-04    2020-05  \
# 0  성동구  82.078993  82.187386  82.202734  82.222013  82.256380  82.265813
# 1  강남구  78.657910  79.304564  79.742271  79.985089  80.112433  80.294087
#
#      2020-06    2020-07    2020-08    2020-09    2020-10    2020-11  \
# 0  82.355565  83.233108  84.346906  86.270024  87.766240  90.416573
# 1  81.085283  82.650809  83.843275  85.358434  86.604845  89.482894
#
#      2020-12    2021-01    2021-02    2021-03    2021-04    2021-05  \
# 0  92.043741  93.273060  93.709073  94.106545  95.249021  95.566938
# 1  91.948129  93.712224  94.266163  94.253195  93.945177  94.040039
#
#      2021-06    2021-07    2021-08    2021-09    2021-10    2021-11  \
# 0  95.880680  96.307936  96.674797  97.794650  98.546872  99.340735
# 1  95.738297  96.740929  97.623798  98.355783  98.816228  99.562264
#
#      2021-12  2022-01     2022-02     2022-03     2022-04     2022-05  \
# 0  99.515696      100  100.316891  100.263137  100.446057  101.008684
# 1  99.867543      100   99.739458   99.431486   99.302198   99.200959
#
#       2022-06     2022-07     2022-08     2022-09    2022-10    2022-11  \
# 0  101.042005  100.826822  100.613455  100.531226  99.908225  97.767300
# 1   99.369518   99.420119   99.230237   99.219235  98.652414  97.419373
#
#      2022-12    2023-01    2023-02    2023-03    2023-04    2023-05  \
# 0  95.246219  91.746536  89.483913  87.583616  86.636863  86.102798
# 1  94.104121  88.019492  83.841633  81.627843  80.611834  80.372513
#
#      2023-06    2023-07    2023-08    2023-09    2023-10    2023-11  \
# 0  86.054190  85.931881  86.284182  86.651243  86.944186  87.360921
# 1  80.625198  81.049797  81.438153  81.770394  82.233577  82.808694
#
#      2023-12    2024-01    2024-02    2024-03    2024-04    2024-05
# 0  87.647818  88.016738  88.232170  88.721050  89.576957  89.997745
# 1  83.228152  83.624761  83.944583  84.266718  84.818628  85.264161

# %%
jeonse_dropped.to_csv('jeonse_dropped.csv', index=False, encoding='utf-8-sig')

# %%
jeonse_dropped_t = jeonse_dropped.T #행을 열로 바꿔주는 코드
jeonse_dropped_t
# Out:
#                   0          1
# 지역명             성동구        강남구
# 2019-12   82.078993   78.65791
# 2020-01   82.187386  79.304564
# 2020-02   82.202734  79.742271
# 2020-03   82.222013  79.985089
# 2020-04    82.25638  80.112433
# 2020-05   82.265813  80.294087
# 2020-06   82.355565  81.085283
# 2020-07   83.233108  82.650809
# 2020-08   84.346906  83.843275
# 2020-09   86.270024  85.358434
# 2020-10    87.76624  86.604845
# 2020-11   90.416573  89.482894
# 2020-12   92.043741  91.948129
# 2021-01    93.27306  93.712224
# 2021-02   93.709073  94.266163
# 2021-03   94.106545  94.253195
# 2021-04   95.249021  93.945177
# 2021-05   95.566938  94.040039
# 2021-06    95.88068  95.738297
# 2021-07   96.307936  96.740929
# 2021-08   96.674797  97.623798
# 2021-09    97.79465  98.355783
# 2021-10   98.546872  98.816228
# 2021-11   99.340735  99.562264
# 2021-12   99.515696  99.867543
# 2022-01         100        100
# 2022-02  100.316891  99.739458
# 2022-03  100.263137  99.431486
# 2022-04  100.446057  99.302198
# 2022-05  101.008684  99.200959
# 2022-06  101.042005  99.369518
# 2022-07  100.826822  99.420119
# 2022-08  100.613455  99.230237
# 2022-09  100.531226  99.219235
# 2022-10   99.908225  98.652414
# 2022-11     97.7673  97.419373
# 2022-12   95.246219  94.104121
# 2023-01   91.746536  88.019492
# 2023-02   89.483913  83.841633
# 2023-03   87.583616  81.627843
# 2023-04   86.636863  80.611834
# 2023-05   86.102798  80.372513
# 2023-06    86.05419  80.625198
# 2023-07   85.931881  81.049797
# 2023-08   86.284182  81.438153
# 2023-09   86.651243  81.770394
# 2023-10   86.944186  82.233577
# 2023-11   87.360921  82.808694
# 2023-12   87.647818  83.228152
# 2024-01   88.016738  83.624761
# 2024-02    88.23217  83.944583
# 2024-03    88.72105  84.266718
# 2024-04   89.576957  84.818628
# 2024-05   89.997745  85.264161

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 준비
data = {
    '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152],
    '2024-01': [88.016738, 83.624761],
    '2024-02': [88.23217, 83.944583],
    '2024-03': [88.72105, 84.266718],
    '2024-04': [89.576957, 84.818628],
    '2024-05': [89.997745, 85.264161]
}

# 데이터프레임 생성
df = pd.DataFrame(data)

# 날짜 열을 인덱스로 설정
df.set_index('지역명', inplace=True)

# 선 그래프 그리기
plt.figure(figsize=(12, 6))

for region in df.index:
    plt.plot(df.columns, df.loc[region], marker='o', label=region)

plt.title('성동구와 강남구의 전세가격 변화')
plt.xlabel('날짜')
plt.ylabel('전세가격')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 준비
data = {
    '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152],
    '2024-01': [88.016738, 83.624761],
    '2024-02': [88.23217, 83.944583],
    '2024-03': [88.72105, 84.266718],
    '2024-04': [89.576957, 84.818628],
    '2024-05': [89.997745, 85.264161]
}

# 데이터프레임 생성
df = pd.DataFrame(data)

# 날짜 열을 인덱스로 설정
df.set_index('지역명', inplace=True)

# 선 그래프 그리기
plt.figure(figsize=(12, 6))

for region in df.index:
    plt.plot(df.columns, df.loc[region], marker='o', label=region)

# 제목과 축 라벨 설정
plt.title('성동구와 강남구의 전세가격 변화')
plt.xlabel('날짜')
plt.ylabel('전세가격 (성동구, 강남구)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#글꼴 에러 해결 코드 - 1
# !apt-get update -qq
# !apt-get install -qq fonts-nanum

# %%
#글꼴 에러 해결 코드 - 2
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd

# Add font and rebuild cache
fm.fontManager.addfont('/usr/share/fonts/truetype/nanum/NanumGothic.ttf')
# Rebuild is automatically triggered when adding a font in current versions

# Set font
plt.rc('font', family='NanumGothic')

# %%
import pandas as pd

# %%
korea_bank = pd.read_csv('/content/drive/MyDrive/개떡찰떡/DATA/korea_bank.csv')

# %%
pd.set_option('display.max_columns', None) # 모든 열을 표시
pd.set_option('display.max_rows', None) # 모든 행을 표시

# %%
korea_bank_t = korea_bank.T

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
import numpy as np
import matplotlib.dates as mdates

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 데이터 준비
data = {
'Date': [
'2019/12', '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
'2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12', '2021/01',
'2021/02', '2021/03', '2021/04', '2021/05', '2021/06', '2021/07', '2021/08',
'2021/09', '2021/10', '2021/11', '2021/12', '2022/01', '2022/02', '2022/03',
'2022/04', '2022/05', '2022/06', '2022/07', '2022/08', '2022/09', '2022/10',
'2022/11', '2022/12', '2023/01', '2023/02', '2023/03', '2023/04', '2023/05',
'2023/06', '2023/07', '2023/08', '2023/09', '2023/10', '2023/11', '2023/12',
'2024/01', '2024/02', '2024/03', '2024/04', '2024/05'
],
'Interest Rate (%)': [
1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
]
}

df = pd.DataFrame(data)

# 날짜 형식으로 변환
df['Date'] = pd.to_datetime(df['Date'], format='%Y/%m')

# 바 그래프 그리기
plt.figure(figsize=(12, 6))
plt.bar(df['Date'], df['Interest Rate (%)'], color='b', width=20)
plt.title('한국은행 기준금리')
plt.xlabel('날짜')
plt.ylabel('기준금리 (%)')

# 날짜 포맷 변경 및 모든 날짜 라벨 표시
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(df['Date'], rotation=45)

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
import numpy as np
import matplotlib.dates as mdates

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 데이터 준비
interest_data = {
    'Date': [
        '2019/12', '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
        '2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12', '2021/01',
        '2021/02', '2021/03', '2021/04', '2021/05', '2021/06', '2021/07', '2021/08',
        '2021/09', '2021/10', '2021/11', '2021/12', '2022/01', '2022/02', '2022/03',
        '2022/04', '2022/05', '2022/06', '2022/07', '2022/08', '2022/09', '2022/10',
        '2022/11', '2022/12', '2023/01', '2023/02', '2023/03', '2023/04', '2023/05',
        '2023/06', '2023/07', '2023/08', '2023/09', '2023/10', '2023/11', '2023/12',
        '2024/01', '2024/02', '2024/03', '2024/04', '2024/05'  # 추가된 부분
    ],
    'Interest Rate (%)': [
        1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
        1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
        3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5  # 기존 데이터와 추가된 부분 모두 포함
    ]
}


jeonse_data = {
    '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152],
    '2024-01': [88.016738, 83.624761],
    '2024-02': [88.23217, 83.944583],
    '2024-03': [88.72105, 84.266718],
    '2024-04': [89.576957, 84.818628],
    '2024-05': [89.997745, 85.264161]
}

# 금리 데이터 프레임 생성
interest_df = pd.DataFrame(interest_data)
interest_df['Date'] = pd.to_datetime(interest_df['Date'], format='%Y/%m')

# 전세 가격 데이터 프레임 생성
jeonse_df = pd.DataFrame(jeonse_data)
jeonse_df.set_index('지역명', inplace=True)

# 결합된 그래프 그리기
fig, ax1 = plt.subplots(figsize=(12, 6))

# 금리 막대 그래프
ax1.bar(interest_df['Date'], interest_df['Interest Rate (%)'], color='b', width=20, alpha=0.6)
ax1.set_xlabel('날짜')
ax1.set_ylabel('기준금리 (%)', color='b')
ax1.tick_params(axis='y', labelcolor='b')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m'))
ax1.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# 전세 가격 선 그래프
ax2 = ax1.twinx()
for region in jeonse_df.index:
    ax2.plot(pd.to_datetime(jeonse_df.columns, format='%Y-%m'), jeonse_df.loc[region], marker='o', label=region)

ax2.set_ylabel('전세가격 (성동구, 강남구)', color='g')
ax2.tick_params(axis='y', labelcolor='g')

fig.tight_layout()
fig.legend(loc="upper left", bbox_to_anchor=(0.1,0.9))
plt.title('한국은행 기준금리 및 성동구와 강남구 전세가격 변화')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-ad486488015c> in <cell line: 90>()
#      88
#      89 # 금리 데이터 프레임 생성
# ---> 90 interest_df = pd.DataFrame(interest_data)
#      91 interest_df['Date'] = pd.to_datetime(interest_df['Date'], format='%Y/%m')
#      92
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     707         elif isinstance(data, dict):
#     708             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710         elif isinstance(data, ma.MaskedArray):
#     711             from numpy.ma import mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     479             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     480
# --> 481     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     482
#     483
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     113         # figure out the index, if necessary
#     114         if index is None:
# --> 115             index = _extract_index(arrays)
#     116         else:
#     117             index = ensure_index(index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     653         lengths = list(set(raw_lengths))
#     654         if len(lengths) > 1:
# --> 655             raise ValueError("All arrays must be of the same length")
#     656
#     657         if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
import numpy as np
import matplotlib.dates as mdates

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 데이터 준비
interest_data = {
    'Date': [
        '2019/12', '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
        '2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12', '2021/01',
        '2021/02', '2021/03', '2021/04', '2021/05', '2021/06', '2021/07', '2021/08',
        '2021/09', '2021/10', '2021/11', '2021/12', '2022/01', '2022/02', '2022/03',
        '2022/04', '2022/05', '2022/06', '2022/07', '2022/08', '2022/09', '2022/10',
        '2022/11', '2022/12', '2023/01', '2023/02', '2023/03', '2023/04', '2023/05',
        '2023/06', '2023/07', '2023/08', '2023/09', '2023/10', '2023/11', '2023/12'
    ],
    'Interest Rate (%)': [
        1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
        1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
        3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
    ]
}

jeonse_data = {
    '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152]
}

# 금리 데이터 프레임 생성
interest_df = pd.DataFrame(interest_data)
interest_df['Date'] = pd.to_datetime(interest_df['Date'], format='%Y/%m')

# 전세 가격 데이터 프레임 생성
jeonse_df = pd.DataFrame(jeonse_data)
jeonse_df.set_index('지역명', inplace=True)

# 결합된 그래프 그리기
fig, ax1 = plt.subplots(figsize=(12, 6))

# 금리 막대 그래프
ax1.bar(interest_df['Date'], interest_df['Interest Rate (%)'], color='b', width=20, alpha=0.6)
ax1.set_xlabel('날짜')
ax1.set_ylabel('기준금리 (%)', color='b')
ax1.tick_params(axis='y', labelcolor='b')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m'))
ax1.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# 전세 가격 선 그래프
ax2 = ax1.twinx()
colors = {'성동구': 'black', '강남구': 'red'}
for region in jeonse_df.index:
    ax2.plot(pd.to_datetime(jeonse_df.columns, format='%Y-%m'), jeonse_df.loc[region], marker='o', label=region, color=colors[region])

ax2.set_ylabel('전세가격 (성동구, 강남구)', color='g')
ax2.tick_params(axis='y', labelcolor='g')

fig.tight_layout()
fig.legend(loc="upper left", bbox_to_anchor=(0.1,0.9))
plt.title('한국은행 기준금리 및 성동구와 강남구 전세가격 변화')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 데이터 준비
interest_data = {
    'Date': [
        '2019/12', '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
        '2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12', '2021/01',
        '2021/02', '2021/03', '2021/04', '2021/05', '2021/06', '2021/07', '2021/08',
        '2021/09', '2021/10', '2021/11', '2021/12', '2022/01', '2022/02', '2022/03',
        '2022/04', '2022/05', '2022/06', '2022/07', '2022/08', '2022/09', '2022/10',
        '2022/11', '2022/12', '2023/01', '2023/02', '2023/03', '2023/04', '2023/05',
        '2023/06', '2023/07', '2023/08', '2023/09', '2023/10', '2023/11', '2023/12'
    ],
    'Interest Rate (%)': [
        1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
        1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
        3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
    ]
}

jeonse_data = {
    '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152]
}

# 금리 데이터 프레임 생성
interest_df = pd.DataFrame(interest_data)
interest_df['Date'] = pd.to_datetime(interest_df['Date'], format='%Y/%m')

# 전세 가격 데이터 프레임 생성
jeonse_df = pd.DataFrame(jeonse_data)
jeonse_df.set_index('지역명', inplace=True)

# 결합된 그래프 그리기
fig, ax1 = plt.subplots(figsize=(12, 6))

# 금리 막대 그래프
ax1.bar(interest_df['Date'], interest_df['Interest Rate (%)'], color='orange', width=20, alpha=0.6)
ax1.set_xlabel('날짜')
ax1.set_ylabel('기준금리 (%)', color='orange')
ax1.tick_params(axis='y', labelcolor='orange')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m'))
ax1.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45)

# 전세 가격 선 그래프
ax2 = ax1.twinx()
ax2.plot(pd.to_datetime(jeonse_df.columns, format='%Y-%m'), jeonse_df.loc['성동구'], marker='o', color='black', label='성동구')
ax2.plot(pd.to_datetime(jeonse_df.columns, format='%Y-%m'), jeonse_df.loc['강남구'], marker='o', color='red', label='강남구')

ax2.set_ylabel('전세가격 (성동구, 강남구)', color='g')
ax2.tick_params(axis='y', labelcolor='g')

fig.tight_layout()
fig.legend(loc="upper left", bbox_to_anchor=(0.1,0.9))
plt.title('한국은행 기준금리 및 성동구와 강남구 전세가격 변화')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 데이터 준비
interest_data = {
    'Date': [
        '2019/12', '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
        '2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12', '2021/01',
        '2021/02', '2021/03', '2021/04', '2021/05', '2021/06', '2021/07', '2021/08',
        '2021/09', '2021/10', '2021/11', '2021/12', '2022/01', '2022/02', '2022/03',
        '2022/04', '2022/05', '2022/06', '2022/07', '2022/08', '2022/09', '2022/10',
        '2022/11', '2022/12', '2023/01', '2023/02', '2023/03', '2023/04', '2023/05',
        '2023/06', '2023/07', '2023/08', '2023/09', '2023/10', '2023/11', '2023/12'
    ],
    'Interest Rate (%)': [
        1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
        1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
        3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
    ]
}

jeonse_data = {
    '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152]
}

# 금리 데이터 프레임 생성
interest_df = pd.DataFrame(interest_data)
interest_df['Date'] = pd.to_datetime(interest_df['Date'], format='%Y/%m')

# 전세 가격 데이터 프레임 생성
jeonse_df = pd.DataFrame(jeonse_data)
jeonse_df.set_index('지역명', inplace=True)

# 결합된 그래프 그리기
fig, ax1 = plt.subplots(figsize=(20, 6))

# 금리 막대 그래프
ax1.bar(interest_df['Date'], interest_df['Interest Rate (%)'], color='orange', width=20, alpha=0.6)
ax1.set_xlabel('날짜', color='black')
ax1.set_ylabel('기준금리 (%)', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m'))
ax1.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45, color='black')
plt.yticks(color='black')

# 전세 가격 선 그래프
ax2 = ax1.twinx()
ax2.plot(pd.to_datetime(jeonse_df.columns, format='%Y-%m'), jeonse_df.loc['성동구'], marker='o', color='black', label='성동구')
ax2.plot(pd.to_datetime(jeonse_df.columns, format='%Y-%m'), jeonse_df.loc['강남구'], marker='o', color='red', label='강남구')

ax2.set_ylabel('전세가격 (성동구, 강남구)', color='black')
ax2.tick_params(axis='y', labelcolor='black')
plt.yticks(color='black')

fig.tight_layout()
fig.legend(loc="upper left", bbox_to_anchor=(0.1,0.9))
plt.title('한국은행 기준금리 및 성동구와 강남구 전세가격 변화', color='black')
plt.show()

# %% [markdown]
# # 한은 기준금리와 성동구&강남구 전세가격의 상관관계

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 데이터 준비
interest_data = {
'Date': [
'2019/12', '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
'2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12', '2021/01',
'2021/02', '2021/03', '2021/04', '2021/05', '2021/06', '2021/07', '2021/08',
'2021/09', '2021/10', '2021/11', '2021/12', '2022/01', '2022/02', '2022/03',
'2022/04', '2022/05', '2022/06', '2022/07', '2022/08', '2022/09', '2022/10',
'2022/11', '2022/12', '2023/01', '2023/02', '2023/03', '2023/04', '2023/05',
'2023/06', '2023/07', '2023/08', '2023/09', '2023/10', '2023/11', '2023/12',
'2024/01', '2024/02', '2024/03', '2024/04', '2024/05'
],
'Interest Rate (%)': [
1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
]
}

jeonse_data = {
     '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152],
    '2024-01': [88.016738, 83.624761],
    '2024-02': [88.23217, 83.944583],
    '2024-03': [88.72105, 84.266718],
    '2024-04': [89.576957, 84.818628],
    '2024-05': [89.997745, 85.264161]
}

# 금리 데이터 프레임 생성
interest_df = pd.DataFrame(interest_data)
interest_df['Date'] = pd.to_datetime(interest_df['Date'], format='%Y/%m')

# 전세 가격 데이터 프레임 생성
jeonse_df = pd.DataFrame(jeonse_data)
jeonse_df.set_index('지역명', inplace=True)

# 결합된 그래프 그리기
fig, ax1 = plt.subplots(figsize=(20, 6))

# 금리 막대 그래프
ax1.bar(interest_df['Date'], interest_df['Interest Rate (%)'], color='orange', width=20, alpha=0.6)
ax1.set_xlabel('날짜', color='black')
ax1.set_ylabel('기준금리 (%)', color='black')
ax1.tick_params(axis='y', labelcolor='black')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y/%m'))
ax1.xaxis.set_major_locator(mdates.MonthLocator())
plt.xticks(rotation=45, color='black')
plt.yticks(color='black')

# 전세 가격 선 그래프
ax2 = ax1.twinx()
ax2.plot(pd.to_datetime(jeonse_df.columns, format='%Y-%m'), jeonse_df.loc['성동구'], marker='o', color='black', label='성동구')
ax2.plot(pd.to_datetime(jeonse_df.columns, format='%Y-%m'), jeonse_df.loc['강남구'], marker='o', color='red', label='강남구')

ax2.set_ylabel('전세가격 (성동구, 강남구)', color='black')
ax2.tick_params(axis='y', labelcolor='black')
plt.yticks(color='black')

fig.tight_layout()
fig.legend(loc="upper left", bbox_to_anchor=(0.1,0.9))
plt.title('한국은행 기준금리 및 성동구와 강남구 전세가격 변화', color='black')
plt.show()

# %%
import pandas as pd

# 데이터 준비
interest_data = {
    'Date': [
        '2019/12', '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
        '2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12', '2021/01',
        '2021/02', '2021/03', '2021/04', '2021/05', '2021/06', '2021/07', '2021/08',
        '2021/09', '2021/10', '2021/11', '2021/12', '2022/01', '2022/02', '2022/03',
        '2022/04', '2022/05', '2022/06', '2022/07', '2022/08', '2022/09', '2022/10',
        '2022/11', '2022/12', '2023/01', '2023/02', '2023/03', '2023/04', '2023/05',
        '2023/06', '2023/07', '2023/08', '2023/09', '2023/10', '2023/11', '2023/12',
        '2024/01', '2024/02', '2024/03', '2024/04', '2024/05'
    ],
    'Interest Rate (%)': [
        1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
        1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
        3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
    ]
}

jeonse_data = {
    '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152],
    '2024-01': [88.016738, 83.624761],
    '2024-02': [88.23217, 83.944583],
    '2024-03': [88.72105, 84.266718],
    '2024-04': [89.576957, 84.818628],
    '2024-05': [89.997745, 85.264161]
}

# 데이터프레임 생성
interest_df = pd.DataFrame(interest_data)
interest_df['Date'] = pd.to_datetime(interest_df['Date'], format='%Y/%m')

# 전세 데이터프레임 생성
jeonse_df = pd.DataFrame(jeonse_data)
jeonse_df.set_index('지역명', inplace=True)

# 인덱스를 날짜 형식으로 변환
jeonse_df.columns = pd.to_datetime(jeonse_df.columns, format='%Y-%m')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 데이터 준비
interest_data = {
    'Date': [
        '2019/12', '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
        '2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12', '2021/01',
        '2021/02', '2021/03', '2021/04', '2021/05', '2021/06', '2021/07', '2021/08',
        '2021/09', '2021/10', '2021/11', '2021/12', '2022/01', '2022/02', '2022/03',
        '2022/04', '2022/05', '2022/06', '2022/07', '2022/08', '2022/09', '2022/10',
        '2022/11', '2022/12', '2023/01', '2023/02', '2023/03', '2023/04', '2023/05',
        '2023/06', '2023/07', '2023/08', '2023/09', '2023/10', '2023/11', '2023/12',
        '2024/01', '2024/02', '2024/03', '2024/04', '2024/05'
    ],
    'Interest Rate (%)': [
        1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
        1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
        3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
    ]
}

jeonse_data = {
    '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152],
    '2024-01': [88.016738, 83.624761],
    '2024-02': [88.23217, 83.944583],
    '2024-03': [88.72105, 84.266718],
    '2024-04': [89.576957, 84.818628],
    '2024-05': [89.997745, 85.264161]
}

# 데이터프레임 생성
interest_df = pd.DataFrame(interest_data)
interest_df['Date'] = pd.to_datetime(interest_df['Date'], format='%Y/%m')

# 전세 데이터프레임 생성
jeonse_df = pd.DataFrame(jeonse_data)
jeonse_df.set_index('지역명', inplace=True)

# 인덱스를 날짜 형식으로 변환
jeonse_df.columns = pd.to_datetime(jeonse_df.columns, format='%Y-%m')

# 데이터프레임 합치기
merged_df = interest_df.merge(jeonse_df.T, left_on='Date', right_index=True)

# 상관계수 계산
correlation = merged_df.corr()['Interest Rate (%)']

print(correlation)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 데이터 준비
interest_data = {
    'Date': [
        '2019/12', '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
        '2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12', '2021/01',
        '2021/02', '2021/03', '2021/04', '2021/05', '2021/06', '2021/07', '2021/08',
        '2021/09', '2021/10', '2021/11', '2021/12', '2022/01', '2022/02', '2022/03',
        '2022/04', '2022/05', '2022/06', '2022/07', '2022/08', '2022/09', '2022/10',
        '2022/11', '2022/12', '2023/01', '2023/02', '2023/03', '2023/04', '2023/05',
        '2023/06', '2023/07', '2023/08', '2023/09', '2023/10', '2023/11', '2023/12',
        '2024/01', '2024/02', '2024/03', '2024/04', '2024/05'
    ],
    'Interest Rate (%)': [
        1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
        1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
        3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
    ]
}

jeonse_data = {
    '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152],
    '2024-01': [88.016738, 83.624761],
    '2024-02': [88.23217, 83.944583],
    '2024-03': [88.72105, 84.266718],
    '2024-04': [89.576957, 84.818628],
    '2024-05': [89.997745, 85.264161]
}

# 데이터프레임 생성
interest_df = pd.DataFrame(interest_data)
interest_df['Date'] = pd.to_datetime(interest_df['Date'], format='%Y/%m')

# 전세 데이터프레임 생성
jeonse_df = pd.DataFrame(jeonse_data)
jeonse_df.set_index('지역명', inplace=True)

# 인덱스를 날짜 형식으로 변환
jeonse_df.columns = pd.to_datetime(jeonse_df.columns, format='%Y-%m')

# 데이터프레임 합치기
merged_df = interest_df.merge(jeonse_df.T, left_on='Date', right_index=True)

# 상관계수 계산
correlation = merged_df.corr()['Interest Rate (%)']

print(correlation)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')

# 데이터 준비
interest_data = {
    'Date': [
        '2019/12', '2020/01', '2020/02', '2020/03', '2020/04', '2020/05', '2020/06',
        '2020/07', '2020/08', '2020/09', '2020/10', '2020/11', '2020/12', '2021/01',
        '2021/02', '2021/03', '2021/04', '2021/05', '2021/06', '2021/07', '2021/08',
        '2021/09', '2021/10', '2021/11', '2021/12', '2022/01', '2022/02', '2022/03',
        '2022/04', '2022/05', '2022/06', '2022/07', '2022/08', '2022/09', '2022/10',
        '2022/11', '2022/12', '2023/01', '2023/02', '2023/03', '2023/04', '2023/05',
        '2023/06', '2023/07', '2023/08', '2023/09', '2023/10', '2023/11', '2023/12',
        '2024/01', '2024/02', '2024/03', '2024/04', '2024/05'
    ],
    'Interest Rate (%)': [
        1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
        1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
        3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
    ]
}

jeonse_data = {
    '지역명': ['성동구', '강남구'],
    '2019-12': [82.078993, 78.65791],
    '2020-01': [82.187386, 79.304564],
    '2020-02': [82.202734, 79.742271],
    '2020-03': [82.222013, 79.985089],
    '2020-04': [82.25638, 80.112433],
    '2020-05': [82.265813, 80.294087],
    '2020-06': [82.355565, 81.085283],
    '2020-07': [83.233108, 82.650809],
    '2020-08': [84.346906, 83.843275],
    '2020-09': [86.270024, 85.358434],
    '2020-10': [87.76624, 86.604845],
    '2020-11': [90.416573, 89.482894],
    '2020-12': [92.043741, 91.948129],
    '2021-01': [93.27306, 93.712224],
    '2021-02': [93.709073, 94.266163],
    '2021-03': [94.106545, 94.253195],
    '2021-04': [95.249021, 93.945177],
    '2021-05': [95.566938, 94.040039],
    '2021-06': [95.88068, 95.738297],
    '2021-07': [96.307936, 96.740929],
    '2021-08': [96.674797, 97.623798],
    '2021-09': [97.79465, 98.355783],
    '2021-10': [98.546872, 98.816228],
    '2021-11': [99.340735, 99.562264],
    '2021-12': [99.515696, 99.867543],
    '2022-01': [100, 100],
    '2022-02': [100.316891, 99.739458],
    '2022-03': [100.263137, 99.431486],
    '2022-04': [100.446057, 99.302198],
    '2022-05': [101.008684, 99.200959],
    '2022-06': [101.042005, 99.369518],
    '2022-07': [100.826822, 99.420119],
    '2022-08': [100.613455, 99.230237],
    '2022-09': [100.531226, 99.219235],
    '2022-10': [99.908225, 98.652414],
    '2022-11': [97.7673, 97.419373],
    '2022-12': [95.246219, 94.104121],
    '2023-01': [91.746536, 88.019492],
    '2023-02': [89.483913, 83.841633],
    '2023-03': [87.583616, 81.627843],
    '2023-04': [86.636863, 80.611834],
    '2023-05': [86.102798, 80.372513],
    '2023-06': [86.05419, 80.625198],
    '2023-07': [85.931881, 81.049797],
    '2023-08': [86.284182, 81.438153],
    '2023-09': [86.651243, 81.770394],
    '2023-10': [86.944186, 82.233577],
    '2023-11': [87.360921, 82.808694],
    '2023-12': [87.647818, 83.228152],
    '2024-01': [88.016738, 83.624761],
    '2024-02': [88.23217, 83.944583],
    '2024-03': [88.72105, 84.266718],
    '2024-04': [89.576957, 84.818628],
    '2024-05': [89.997745, 85.264161]
}

# 데이터프레임 생성
interest_df = pd.DataFrame(interest_data)
interest_df['Date'] = pd.to_datetime(interest_df['Date'], format='%Y/%m')

# 전세 데이터프레임 생성
jeonse_df = pd.DataFrame(jeonse_data)
jeonse_df.set_index('지역명', inplace=True)

# 인덱스를 날짜 형식으로 변환
jeonse_df.columns = pd.to_datetime(jeonse_df.columns, format='%Y-%m')

# 데이터프레임 합치기
merged_df = interest_df.merge(jeonse_df.T, left_on='Date', right_index=True)

# 상관계수 계산
correlation = merged_df.corr()['Interest Rate (%)']

print(correlation)
# Out:
# Date                 0.899840
# Interest Rate (%)    1.000000
# 성동구                 -0.122831
# 강남구                 -0.319888
# Name: Interest Rate (%), dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 데이터 준비
interest_data = {
    'Date': pd.date_range(start='2019-12-01', end='2024-05-01', freq='MS'),
    'Interest Rate (%)': [
        1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
        1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
        3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
    ]
}

jeonse_data = {
    'Date': pd.date_range(start='2019-12-01', end='2024-05-01', freq='MS'),
    '성동구': [
        82.078993, 82.187386, 82.202734, 82.222013, 82.25638, 82.265813, 82.355565,
        83.233108, 84.346906, 86.270024, 87.76624, 90.416573, 92.043741, 93.27306,
        93.709073, 94.106545, 95.249021, 95.566938, 95.88068, 96.307936, 96.674797,
        97.79465, 98.546872, 99.340735, 99.515696, 100, 100.316891, 100.263137,
        100.446057, 101.008684, 101.042005, 100.826822, 100.613455, 100.531226,
        99.908225, 97.7673, 95.246219, 91.746536, 89.483913, 87.583616, 86.636863,
        86.102798, 86.05419, 85.931881, 86.284182, 86.651243, 86.944186, 87.360921,
        87.647818, 88.016738, 88.23217, 88.72105, 89.576957, 89.997745
    ],
    '강남구': [
        78.65791, 79.304564, 79.742271, 79.985089, 80.112433, 80.294087, 81.085283,
        82.650809, 83.843275, 85.358434, 86.604845, 89.482894, 91.948129, 93.712224,
        94.266163, 94.253195, 93.945177, 94.040039, 95.738297, 96.740929, 97.623798,
        98.355783, 98.816228, 99.562264, 99.867543, 100, 99.739458, 99.431486,
        99.302198, 99.200959, 99.369518, 99.420119, 99.230237, 99.219235, 98.652414,
        97.419373, 94.104121, 88.019492, 83.841633, 81.627843, 80.611834, 80.372513,
        80.625198, 81.049797, 81.438153, 81.770394, 82.233577, 82.808694, 83.228152,
        83.624761, 83.944583, 84.266718, 84.818628, 85.264161
    ]
}

# 데이터프레임 생성
interest_df = pd.DataFrame(interest_data)
jeonse_df = pd.DataFrame(jeonse_data)

# 데이터 프레임 합치기
merged_df = interest_df.merge(jeonse_df, on='Date')

# 상관계수 계산
correlation = merged_df[['Interest Rate (%)', '성동구', '강남구']].corr()

# 상관관계 히트맵 그리기
plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#글꼴 에러 해결 코드 - 1
# !apt-get update -qq
# !apt-get install -qq fonts-nanum

# %%
#글꼴 에러 해결 코드 - 2
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd

# Add font and rebuild cache
fm.fontManager.addfont('/usr/share/fonts/truetype/nanum/NanumGothic.ttf')
# Rebuild is automatically triggered when adding a font in current versions

# Set font
plt.rc('font', family='NanumGothic')

# %%
correlation = merged_df[['Interest Rate (%)', '성동구', '강남구']].corr()
correlation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9d8bb0d85469> in <cell line: 1>()
# ----> 1 correlation = merged_df[['Interest Rate (%)', '성동구', '강남구']].corr()
#       2 correlation
#
# NameError: name 'merged_df' is not defined

# %% [markdown]
# ## Interest Rate (%)와 성동구 전세 가격 (성동구): 상관 계수: -0.122831
# ## Interest Rate (%)와 강남구 전세 가격 (강남구): 상관 계수: -0.319888
# ## 성동구 전세 가격 (성동구)와 강남구 전세 가격 (강남구): 상관 계수: 0.974300
#
# ###성동구와 강남구의 전세 가격 사이에는 매우 강한 양의 선형 관계가 있습니다. 즉, 성동구의 전세 가격이 오르면 강남구의 전세 가격도 거의 비슷한 정도로 오를 가능성이 높습니다. 이는 두 지역이 부동산 시장에서 밀접하게 연결되어 있음을 나타냅니다.

# %%
import pandas as pd
import statsmodels.api as sm

# 데이터 준비
interest_data = {
    'Date': pd.date_range(start='2019-12-01', end='2024-05-01', freq='MS'),
    'Interest Rate (%)': [
        1.25, 1.25, 1.25, 0.75, 0.75, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75, 0.75, 0.75, 1.0, 1.0, 1.25, 1.25, 1.25,
        1.5, 1.75, 1.75, 2.25, 2.5, 2.5, 3.0, 3.25, 3.25, 3.5, 3.5, 3.5, 3.5, 3.5,
        3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5, 3.5
    ]
}

jeonse_data = {
    'Date': pd.date_range(start='2019-12-01', end='2024-05-01', freq='MS'),
    '성동구': [
        82.078993, 82.187386, 82.202734, 82.222013, 82.25638, 82.265813, 82.355565,
        83.233108, 84.346906, 86.270024, 87.76624, 90.416573, 92.043741, 93.27306,
        93.709073, 94.106545, 95.249021, 95.566938, 95.88068, 96.307936, 96.674797,
        97.79465, 98.546872, 99.340735, 99.515696, 100, 100.316891, 100.263137,
        100.446057, 101.008684, 101.042005, 100.826822, 100.613455, 100.531226,
        99.908225, 97.7673, 95.246219, 91.746536, 89.483913, 87.583616, 86.636863,
        86.102798, 86.05419, 85.931881, 86.284182, 86.651243, 86.944186, 87.360921,
        87.647818, 88.016738, 88.23217, 88.72105, 89.576957, 89.997745
    ],
    '강남구': [
        78.65791, 79.304564, 79.742271, 79.985089, 80.112433, 80.294087, 81.085283,
        82.650809, 83.843275, 85.358434, 86.604845, 89.482894, 91.948129, 93.712224,
        94.266163, 94.253195, 93.945177, 94.040039, 95.738297, 96.740929, 97.623798,
        98.355783, 98.816228, 99.562264, 99.867543, 100, 99.739458, 99.431486,
        99.302198, 99.200959, 99.369518, 99.420119, 99.230237, 99.219235, 98.652414,
        97.419373, 94.104121, 88.019492, 83.841633, 81.627843, 80.611834, 80.372513,
        80.625198, 81.049797, 81.438153, 81.770394, 82.233577, 82.808694, 83.228152,
        83.624761, 83.944583, 84.266718, 84.818628, 85.264161
    ]
}

interest_df = pd.DataFrame(interest_data)
jeonse_df = pd.DataFrame(jeonse_data)

# 데이터 병합
merged_df = pd.merge(interest_df, jeonse_df, on='Date')

# 다중 회귀 분석
X = merged_df[['성동구', '강남구']]
Y = merged_df['Interest Rate (%)']

X = sm.add_constant(X)  # 절편 추가
model = sm.OLS(Y, X).fit()

# 결과 출력
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Interest Rate (%)   R-squared:                       0.805
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     105.3
# Date:                Tue, 18 Jun 2024   Prob (F-statistic):           7.75e-19
# Time:                        08:38:24   Log-Likelihood:                -46.135
# No. Observations:                  54   AIC:                             98.27
# Df Residuals:                      51   BIC:                             104.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -7.8815      1.412     -5.582      0.000     -10.716      -5.047
# 성동구            0.7459      0.055     13.562      0.000       0.635       0.856
# 강남구           -0.6546      0.046    -14.379      0.000      -0.746      -0.563
# ==============================================================================
# Omnibus:                       13.534   Durbin-Watson:                   0.510
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               19.989
# Skew:                           0.817   Prob(JB):                     4.56e-05
# Kurtosis:                       5.493   Cond. No.                     2.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# R-squared: 0.805
# R-squared 값은 모델이 데이터를 얼마나 잘 설명하는지를 나타내는 지표입니다.
#
# R-squared가 0.805라는 것은 이 회귀 모델이 금리 변동의 약 80.5%를 성동구와 강남구의 전세 가격으로 설명할 수 있다는 것을 의미합니다.
# 쉽게 말하면, 금리가 어떻게 변하는지 알기 위해 이 모델을 사용했을 때, 금리 변동의 80.5%는 전세 가격 변화로 설명할 수 있다는 뜻입니다. 이는 모델이 상당히 잘 맞는다는 것을 의미합니다.
# Adj. R-squared: 0.797
# 조정된 R-squared (Adjusted R-squared) 값은 R-squared 값을 조정하여, 모델에 포함된 변수의 수를 고려한 값입니다.
#
# 조정된 R-squared가 0.797이라는 것은, 모델이 약간 복잡해졌지만 여전히 높은 설명력을 유지한다는 것을 의미합니다.
# 즉, 이 값은 모델에 쓸모없는 변수를 많이 포함시킬 경우 R-squared 값이 높아지는 문제를 방지하기 위한 것으로, 이 모델은 불필요한 변수가 많지 않고 잘 맞는다는 뜻입니다.
# F-statistic: 105.3 and Prob (F-statistic): 7.75e-19
# F-통계량은 모델이 유의미한지를 판단하는 데 사용되는 값입니다.
#
# F-통계량이 105.3이라는 것은 모델이 전체적으로 유의미한 설명력을 가지고 있다는 강한 증거입니다.
# Prob (F-statistic)가 7.75e-19이라는 것은 이 F-통계량이 우연히 발생할 확률이 거의 없다는 것을 의미합니다.
# 쉽게 말하면, 이 모델이 전혀 쓸모없는 모델일 가능성은 매우 낮다는 뜻입니다. 모델이 데이터의 패턴을 잘 설명하고 있다는 것을 강하게 뒷받침하는 증거입니다.
#
# 요약하자면, 이 모델은 금리 변동의 80.5%를 성동구와 강남구의 전세 가격으로 잘 설명하고 있으며, 통계적으로 유의미한 결과를 보여주고 있습니다.

# %% [markdown]
# 시계열 데이터의 상관관계 분석 - 제한조건이 뭔지

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 예시 데이터 준비
jeonse_data = {
    '날짜': [
        '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
        '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12', '2021-01',
        '2021-02', '2021-03', '2021-04', '2021-05', '2021-06', '2021-07', '2021-08',
        '2021-09', '2021-10', '2021-11', '2021-12', '2022-01', '2022-02', '2022-03',
        '2022-04', '2022-05', '2022-06', '2022-07', '2022-08', '2022-09', '2022-10',
        '2022-11', '2022-12', '2023-01', '2023-02', '2023-03', '2023-04', '2023-05',
        '2023-06', '2023-07', '2023-08', '2023-09', '2023-10', '2023-11', '2023-12'
    ],
    '성동구': [
        82.078993, 82.187386, 82.202734, 82.222013, 82.25638, 82.265813, 82.355565,
        83.233108, 84.346906, 86.270024, 87.76624, 90.416573, 92.043741, 93.27306,
        93.709073, 94.106545, 95.249021, 95.566938, 95.88068, 96.307936, 96.674797,
        97.79465, 98.546872, 99.340735, 99.515696, 100, 100.316891, 100.263137,
        100.446057, 101.008684, 101.042005, 100.826822, 100.613455, 100.531226,
        99.908225, 97.7673, 95.246219, 91.746536, 89.483913, 87.583616, 86.636863,
        86.102798, 86.05419, 85.931881, 86.284182, 86.651243, 86.944186, 87.360921,
        87.647818
    ],
    '강남구': [
        78.65791, 79.304564, 79.742271, 79.985089, 80.112433, 80.294087, 81.085283,
        82.650809, 83.843275, 85.358434, 86.604845, 89.482894, 91.948129, 93.712224,
        94.266163, 94.253195, 93.945177, 94.040039, 95.738297, 96.740929, 97.623798,
        98.355783, 98.816228, 99.562264, 99.867543, 100, 99.739458, 99.431486,
        99.302198, 99.200959, 99.369518, 99.420119, 99.230237, 99.219235, 98.652414,
        97.419373, 94.104121, 88.019492, 83.841633, 81.627843, 80.611834, 80.372513,
        80.625198, 81.049797, 81.438153, 81.770394, 82.233577, 82.808694, 83.228152
    ]
}

# 데이터 프레임 생성
jeonse_df = pd.DataFrame(jeonse_data)
jeonse_df.set_index('날짜', inplace=True)  # 날짜를 인덱스로 설정

# 기준금리와 성동구 전세가격의 상관계수 계산
# 여기서는 예시 데이터로 기준금리를 1.25로 설정하고 계산합니다
interest_rate = 1.25
correlation_seongdong = jeonse_df['성동구'].corr(pd.Series([interest_rate] * len(jeonse_df)))
correlation_gangnam = jeonse_df['강남구'].corr(pd.Series([interest_rate] * len(jeonse_df)))

print(f"기준금리와 성동구 전세가격의 상관계수: {correlation_seongdong}")
print(f"기준금리와 강남구 전세가격의 상관계수: {correlation_gangnam}")

# 시각화 예시: 기준금리와 성동구, 강남구 전세가격 시계열 데이터 그래프
plt.figure(figsize=(12, 6))
plt.plot(jeonse_df.index, jeonse_df['성동구'], marker='o', label='성동구 전세가격')
plt.plot(jeonse_df.index, jeonse_df['강남구'], marker='o', label='강남구 전세가격')
plt.axhline(y=interest_rate, color='r', linestyle='--', label='기준금리')
plt.xlabel('날짜')
plt.ylabel('전세가격')
plt.title('기준금리 및 성동구, 강남구 전세가격 시계열 데이터')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 기준금리와 성동구 전세가격의 상관계수: nan
# 기준금리와 강남구 전세가격의 상관계수: nan
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 48143 (\N{HANGUL SYLLABLE MIC}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   plt.tight_layout()
# <ipython-input-2-d2af816ed0a5>:60: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48143 (\N{HANGUL SYLLABLE MIC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44228 (\N{HANGUL SYLLABLE GYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50676 (\N{HANGUL SYLLABLE YEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45936 (\N{HANGUL SYLLABLE DE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53552 (\N{HANGUL SYLLABLE TEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
